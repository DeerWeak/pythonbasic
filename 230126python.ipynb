# %%
import pandas as pd
import numpy as np
import seaborn as sns
# titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
titanic.dropna(subset=["age"], inplace=True)
titanic.count()
# Out:
# survived       714
# pclass         714
# sex            714
# age            714
# sibsp          714
# parch          714
# fare           714
# embarked       712
# class          714
# who            714
# adult_male     714
# deck           184
# embark_town    712
# alive          714
# alone          714
# dtype: int64

# %% [markdown]
# dropna(): Dataframe내의 결측지 제거

# %%
titanic["adult_feamle"] = (titanic["sex"] == "female") & (titanic["age"] >= 20)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

global_font = {'family': 'NanumGothic', 'size':12, 'weight':'bold'}

# 폰트 설정
mpl.rc('font', **global_font) # pass in the font dict as kwargs
# mpl.rc('font', 'family': 'NanumGothic', 'size':24, 'weight': 'bold')와 같이 동작합니다.

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 레이블")
plt.ylabel("와이축 레이블")
plt.show()

# %%
import matplotlib.font_manager as font_manager
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['C:/python/fonts']
for font in font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name()) # 이름 확인
    font_manager.fontManager.addfont(font) # 폰트 추가
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# ['Noto Sans KR']

# %%
plt.title("한글")
# Out:
# Text(0.5, 1.0, '한글')

# %%
mpl.rc('axes', unicode_minus=False) #유니코드 마이너스를 아스키 마이너스로 변경

# %%
ax1 = plt.subplot(2, 1, 1)
ax2 = plt.subplot(2, 1, 2)

# %% [markdown]
# 위/아래 두 개의 플롯을 하나의 figure안에 그리려면 다음처럼 명령 실행. 여기에서 숫자 인덱싱은 파이썬이 아닌 matlab 관행을 따르기 때문에 첫번째 플롯을 가리키는 숫자가 0이 아니라 1임에 주의해야 함.

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x1, y1, 'r.-')
plt.title('time (s)')
plt.ylabel('undamped')

plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# Axis
# 여러가지 플롯을 하나의 axes 객체에 표시할 때 y값의 크기가 달라서 표시하기 힘든 경우가 있습니ㅏㄷ. 이때는 다음처럼 twinx명령으로 대해 복수의

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g: ', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19692\1035212645.py in <module>
#       5 ax0.set_ylabel("y0")
#       6 ax0.grid(False)
# ----> 7 ax1.plot([100, 200, 220, 180, 120], 'g: ', label="y1")
#       8 ax1.set_ylabel("y1")
#       9 ax1.grid(False)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# ...

# %% [markdown]
# ### 바 차트
# x 데이터가 카테고리 값인 경우에는 bar명령과 barh명령으로 바 차트 시각화 가능. 가로 방향으로 바 차트 그리려면 barh 명령 사용.
# 바 차트 작성 시 주의점은 첫번째 인수인 left가 x축에서 바의 왼쪽 변의 위치를 나타낸다는 점.

# %%
y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
x = ['가', '나', '다']
y = [2, 3, 1]
colors = ["red", "green", "blue"]

plt.title("Bar Chart")
plt.bar(x, y, color = colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr = error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
alive_x = ["사망자", "생존자"]
alive_y = pd.value_counts(titanic["alive"])
colors = ["red", "green"]

plt.title("타이타닉호 생존 여부")
plt.grid(True)
plt.barh(alive_x, alive_y, color = colors, alpha = 0.6)
plt.show()

# %%
bar_chart = titanic["alive"].value_counts()
bar_chart.rename({'no':'사망자', 'yes':'생존자'}, inplace = True)
print(bar_chart)
alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

plt.title("타이타닉호 생존 여부")
plt.barh(alive, value, color=bar_colors)
plt.xlabel("인원 수")
plt.show()
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19692\3893055377.py in <module>
#       8 plt.title("타이타닉호 생존 여부")
#       9 plt.barh(alive, value, color=bar_colors)
# ---> 10 plt.xlabel("인원 수")
#      11 plt.show()
#
# TypeError: 'list' object is not callable

# %%
fig, ax = plt.subplots()

alive = bar_chart.index
value = bar_chart.values

ax.set_title("타이타닉호 생존 여부")
ax.barh(alive, value, color=bar_colors)
ax.set_xlabel("인원 수")
plt.show()

# %%
#파이 차트
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0) # 파이에서 0.1만큼 떨어져라
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors = colors, 
        autopct = '%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # 원의 형태를 유지
plt.show()

# %% [markdown]
# 아래 것 pdf 보고 다시 하기

# %%
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]

cats = pd.cut(titanic.age, bins, labels=labels)
cats = cats[cats.notnull()]

explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

plt.pie(cats.value_counts(), explode = explode, labels = labels, colors = colors, 
        autopct = '%1.1f%%', shadow=True, startangle=90)
plt.show()

# %% [markdown]
# ### 히스토그램.
# 히스토그램을 그리기 위한 hist 명령. bins 인수로 데이터를 집계할 구간 정보를 받는다.

# %%
np.random.seed(0)
x=np.random.randn(1000)
plt.title("Histogram")
arrays, bines, patches = plt.hist(x, bins=10)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
np.random.seed(00)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서 2차원 자료의 크기를 색깔로 표시하는 것이다.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits: 0")
plt.imshow(X, interpolation = 'nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %% [markdown]
# 데이터 수치를 색으로 바꾸는 함수는 칼라맵(Color MAP)이라고 한다. 칼라맵은 cmap 인수로 지정한다. 사용할 수 있는 칼라맵은 plt.cm의 속성으로 포함되어 있따. 아래에 일부 칼라맵을 표시하였따.

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3),
                         subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation='nearest', cmap='BrBG')
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation='nearest', cmap='BrBG_r')
plt.show()

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %% [markdown]
# ### 컨투어 플롯
# 입력 변수가 x, y 두 개이고 출력 변수가

# %%
def f(x, y):
    return (1 - x/2 + x**5 + y**3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha=.75, cmap='jet')
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %% [markdown]
# 3차원 츨롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시한다
# plot_wireframe(), plot_surface() 명령을 사용한다.

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D Surface Plot')
ax.plot_surface(XX, YY,ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\peter\AppData\Local\Temp\ipykernel_19692\2058423391.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
titanic.to_csv("titanic_age.csv", index=False, encoding="UTF-8")
titanic_age = pd.read_csv("titanic_age.csv")
titanic_age
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 타이타닉호 데이터셋을 새롭게 불러옵니다. 그 후 티켓 클래스(pclass)에 따른 생존율을 비교해보세요.
# - survived가 1이면 생존 0이면 사망입니다.
# - groupby() 메서드를 활용해보세요.

# %%
titanic[["pclass", "survived"]].groupby(["pclass"]).mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
groups = titanic.groupby(["pclass"])
groups.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
groups.mean()
# Out:
#         survived        age     sibsp     parch       fare  adult_male  \
# pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687    0.550926
# 2       0.472826  29.877630  0.402174  0.380435  20.662183    0.538043
# 3       0.242363  25.140620  0.615071  0.393075  13.675550    0.649695
#
#            alone
# pclass
# 1       0.504630
# 2       0.565217
# 3       0.659878

# %%
groups.mean()["survived"]
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
groups.mean()[["survived"]]
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
titanic[["pclass", "survived"]].groupby(titanic["pclass"]).sum()
# Out:
#         pclass  survived
# pclass
# 1          216       136
# 2          368        87
# 3         1473       119

# %% [markdown]
# 타이타닉호 데이터셋에서 성별에 따른 생존율을 비교해보세요.

# %%
titanic[["sex", "survived"]].groupby(["sex"]).mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic[["pclass", "sex", "survived"]].groupby(["sex"]).mean()
# Out:
#           pclass  survived
# sex
# female  2.159236  0.742038
# male    2.389948  0.188908

# %% [markdown]
# ### Seaborn
# seaborn은 matplotlib을 기반으로 다양한 색상 테마와 통계용 차트 등의 기능을 추가한 시각화 패키지입니다.
# 기본적인 시각화 기능은 matplotlib 패키지에 읜존하며 통계 기능은 statsmodels패키지에 의존합니다.

# %% [markdown]
# ### 카운트 플롯
# countplot()을 사용하면 각 카테고리 값마다의 데이터가 얼마나 있는지 표시할 수 있습니다. 카운트 플롯은 카테고리별 히스토그램이라고 볼 수 있습니다.   API와 옵션은 바차트와 동일합니다.
# seaborn.countplot()

# %% [markdown]
# set_theme()는 global 범위의 테마를 적용해서 그래프를 쉽게 꾸밀 수 있습니다. style과 palette 키워드 인수를 활용해서 그 값을 설정합니다.
# - style: darkgrid, whitegrid, dark, white, ticks, ...
# - palette: pastel, husl, Spectral, flare, ...
# ```
# import searborn as sns
# sns.set_thme(style="whitegrid")
# ```
# 참고) set_context()의 인수로 paper, notebook, talk, poster 중 하나를 넣으면 해당하는 설정을 세팅할 수 있습니다.

# %% [markdown]
# ### 카운트 플롯
# class는 선실의 등급을 나타내는 columns. 마치 value_counts()의 결과를 보듯한 바차트를 볼 수 있습니다. 각 유니크한 값들이 몇개씩 있는지 시각적으로 확인 가능.

# %%
df = sns.load_dataset("titanic")
sns.countplot(x=df["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# x 키워드 인수에 Series를 전달하고 있습니다. 해당 Series에 있는 값을 유니크하게 가져와서 카운트한 결과를 가져오는 것을 확인할 수 있습니다.

# %% [markdown]
# hue 키워드 인수를 활용하여 분류할 두 번째 변수를 설정할 수 있습니다. 여기서는 alive를 column을 지정하였고 선실별 생존 여부를 가시적으로 확인할 수 있게 돕고 있습니다.

# %%
# group by second variable
sns.countplot(data=df, x="class", hue="alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# 여기서는 data 키워드 인수에 DataFrame을 전달하고 x키워드 인수에 DataFrame 중 매칭하고 싶은 column의 name 값을 전달하고 있습니다. 뿐만 아니라 hue 키워드 인수에도 DataFrame의 column name을 전달하고 있음을 주목하세요.

# %% [markdown]
# 플롯을 수평하게도 작성할 수 있습니다. y키워드 인수에 data로 넘긴 DataFrame의 column name값을 전달하면 됩니다. 아래 예제에서는 그래프를 수평하게 표현하여 카테고리 레이블을 나타내는 legend(범례) 공간을 확보했습니다.

# %%
sns.countplot(data=df, y="deck", hue="alive")
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %% [markdown]
# ### tips 데이터셋
# 각 column마다의 의미는 다음과 같습니다.
# - total_bill: 총 지불 금액
# - tip: 팁
# - sex: 성별
# - smoker:흡연 여부
# - day: 요일
# - time: 식사 시간애
# - size: 식사 인원

# %% [markdown]
# ### rugplot()
# 러그 플롯은 데이터 위치를 x축 위에 작은 선분(rug)으로 나타내어 실제 데이터들의 위치를 보여준다.
#
# 커널 밀도(kernel density)는 커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여주는 방법이다.

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.kdeplot(data = tips, x="total_bill")
sns.rugplot(data = tips, x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
# Add a rug along both axes
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# represent a third variable with hue mapping
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
sns.rugplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Add a rug along both axes
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip", height=0.1) # height 전체 크기 대비 비율. 여기서는 10%
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset("diamonds")
sns.scatterplot(data=diamonds, x="carat", y="price", s=5)
sns.rugplot(data=diamonds, x="carat", y="price", lw=1, alpha=0.005)
# 데이터가 너무 많아 밀도가 높아 안보일 경우 투명도 조정
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - species: 펭귄의 종(Chinstrap, Adélie, Gentoo)
# - culmen_length_mm: culmen length (mm)
# - culmen_depth_mm: culmen depth (mm)
# - flipper_length_mm: flipper length (mm)
# - body_mass_g: 체중(g)
# - island: 서식지 섬 (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# - sex: 펭귄 성별species: 펭귄의 종(Chinstrap, Adélie, Gentoo)
# - culmen_length_mm: culmen length (mm)
# - culmen_depth_mm: culmen depth (mm)
# - flipper_length_mm: flipper length (mm)
# - body_mass_g: 체중(g)
# - island: 서식지 섬 (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# - sex: 펭귄 성별
#
# ![image.png](attachment:3f037876-0f62-48ee-9ad2-d930dc2a33eb.png)![image.png](attachment:9f3c39fb-7c05-4a8c-9bb9-61e06534aee0.png)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# flipper길이에 대한 분포를 x축 기준으로 히스토그램을 나타냄. data로 DataFrame을 전달하고 x키워드 인수로 columns label값을 전달하고 있습니다. 히스토그램을 보면 좌측 y축은 개수를 표현하고 있습니다.

# %%
sns.histplot(data = penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# y축을 기준으로 히스토그램을 표현하고 있습니다. x키워드 인수를 y키워드 인수로 변경하여 표현함

# %%
sns.histplot(data=penguins, y="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='flipper_length_mm'>

# %% [markdown]
# binwidth 키워드 인수를 사용하면 bin의 너비를 지정할 수 있습니다. 현재는 3으로 값을 줘서 3의 범위만큼 히스토그램이 표현되는 것을 확인할 수 있습니다.

# %%
sns.histplot(data=penguins, x="flipper_length_mm", binwidth=3)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# 막대 개수 30개(bins)
sns.histplot(data=penguins, x="flipper_length_mm", bins=30)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### 히스토그램 - histplot() kde를 동시에 표시하기
# kde는 kernel density의 약자로 커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여줍니다. 아래 코드에서는 kde 키워드 인수에 True 값을 전달하여 히스토그램과 kde 그래프를 동시에 출력하소 있습니다.

# %%
# Add a kernel density estimate to smooth the histogram,
# providing complemntary information about the shape of the distrubution
sns.histplot(data=penguins, x="flipper_length_mm", kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### 히스토그램 -histplot() hue 키워드 인수로 데이터 분리하기
# hue 키워드 인수에 분류 기준이 될 column label을 전달해서 여러 개의 히스토그램을 합친 것과 같은 결과의 그래프를 얻을 수 있습니다. 펭귄의 종류마다 분포를 나눴기 때문에 이제야 분포가 더 명확하게 보이는 것을 확인할 수 있습니다.

# %%
#ㅇㄱㅁㅈ ㅡㅕㅣ샤ㅔㅣㄷ ㅗㅑㄴ샑믄 ㄹ개ㅡ ㅁ ㅣㅐㅜㅎ-래그 ㅇㅁㅅㄴㄷㅅ 쟈소 ㅗㅕㄷ ㅡ메ㅔㅑㅜㅎ
sns.histplot(data = penguins, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# 앞서 살펴봤던 예제는 각 히스토그램의 layer가 겹쳐서 표현됐다면 이를 누적하듯 표현하는 방법도 있습니다. multiple 키워드 인수에 "stack"값을 전달하면 됩니다. 펭귄의 종류별 누적 히스토그램을 아래와 같이 확인할 수 있습니다.

# %%
# can also "stack" them
sns.histplot(data = penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# 오버래핑된 결과가 보기 힘들 떄의 해결 방법 중 하나로 elements 키워드 인수에 'step'이란 값을 전달하여 아래의 그래프처럼 표현할 수 있습니다.

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# 다각형 형태로도 표현 가능합니다. element 키워드 인수에 'poly' 값을 전달하면 됩니다.
# 이는 전체적인 모양을 살피는데 더 유용합니다.

# %%
sns.histplot(penguins, x="flipper_length_mm", hue = "species", element="poly")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# x축과 y축 모두 column을 할당하게 되면 히트맵(heatmap)형태의 히스토그램을 표현합니다.

# %%
sns.histplot(penguins, x="bill_depth_mm", y="body_mass_g", hue="species")
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# x축과 y축 모두 column을 할당할 떄 그 중 하나의 값이 이산된 값이라면 아래와 같이 데이터를 시각화하여 표현하면 훨씬 이해가 쉽게 표현할 수 있습니다.

# %%
sns.histplot(
    penguins, x="bill_depth_mm", y="species", hue="species", legend=False
)
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='species'>

# %% [markdown]
# ### 히스토그램 - displot()
# displot()도 마찬가지로 1차원 혹은 2차원 데이터의 분포를 히스토그램으로 보여줍니다. 다만 rug와 kde에 대해 동시에 표현이 가능해서 표현 범위가 더 넓고 이에 따라 많이 사용됩니다.

# %% [markdown]
# 기본적인 형태의 히스토그램을 그리고 있습니다. histplot()과 동일한 인수와 그래프 모양을 보여줍니다.

# %%
sns.displot(data=penguins, x="flipper_length_mm")

# %% [markdown]
# kind 키워드 인수를 활용해서 기본적으로 표현된는 히ㅅ토그램의 종류를 kde로 변경했습니다.
# kde는 부드러운 곡선

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")

# %% [markdown]
# 이번에는 kind 키워드 인수에 ecdf(empirical cumulative distribution functions)를 활용해서 누적 분포 그래프로 표현하고 있습니다.

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf")

# %% [markdown]
# kde 키워드 인수 값을 True로 전달하여 히스토그램과 kde를 동시에 표현하고 있습니다. 앞에서의 kind=kde와 비교해서 차이점을 생각해보세요.

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True)

# %% [markdown]
# histplot()과 동일하게 x와 y에 각각 값을 할당하여 히트맵 형태로 그래프를 출력할 수 있습니다.

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
g = sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde", rug=True)
