# %%
import pandas as pd
import numpy as np
import seaborn as sns
# titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")

# %% [markdown]
# ### 퀴즈3

# %%
ndarray1 = np.arange(2, 21, 3)
ndarray1
# Out:
# array([ 2,  5,  8, 11, 14, 17, 20])

# %% [markdown]
# self란 클래스로 생성된 객체 자신을 의미합니다.

# %% [markdown]
# float

# %% [markdown]
# 3

# %%
df = pd.Series({"일":1,
                "이":2,
                "삼":3})
df
# Out:
# 일    1
# 이    2
# 삼    3
# dtype: int64

# %% [markdown]
# 2, 5

# %% [markdown]
# 5 -> universal function

# %% [markdown]
# 8) 1, 3, 4, 5

# %% [markdown]
# 9) 3

# %% [markdown]
# 10) 5 -> series의 형태로 값 반환

# %%
df1 = pd.DataFrame({
    '품종': ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이': [1.4, 1.3, 1.5, 1.3]},
    columns = ['품종', '꽃잎길이'])
df1
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
df2 = pd.DataFrame({
    '품종': ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비': [0.4, 0.3, 0.5, 0.3]},
    columns = ['품종', '꽃잎너비'])
df2
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
pd.merge(df1, df2)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %% [markdown]
# pd.to_datetime 함수를 쓰면 날짜/시간을 나타내느 문자열을 자동으로 datetime 자료형으로 바꾼 후 DatetimeIndex 자료형 인덱스를 생성합니다.

# %%
date_str = ["2018, 1, 1", "2018, 1, 4", "2018, 1, 5", "2018, 1, 6"]
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-04', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
np.random.seed(0)
s = pd.Series(np.random.randn(4), index=idx)
s
# Out:
# 2018-01-01    1.764052
# 2018-01-04    0.400157
# 2018-01-05    0.978738
# 2018-01-06    2.240893
# dtype: float64

# %%
pd.date_range("2018-4-1", "2018-4-30")
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2018-4-1", periods=30)
# Out:
# DatetimeIndex(['2018-04-01', '2018-04-02', '2018-04-03', '2018-04-04',
#                '2018-04-05', '2018-04-06', '2018-04-07', '2018-04-08',
#                '2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18', '2018-04-19', '2018-04-20',
#                '2018-04-21', '2018-04-22', '2018-04-23', '2018-04-24',
#                '2018-04-25', '2018-04-26', '2018-04-27', '2018-04-28',
#                '2018-04-29', '2018-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# freq 인수로 특정한 날짜만 생성되도록 할 수도 있습니다. 많이 사용되는 freq 인수값은 다음과 같습니다.
# - s: 초
# - T: 분
# - H: 시간
# - D: 일(day)
# - B: 주말이 아닌 평일
# - W: 주(일요일)
# - W-MON: 주(월요일)
# - M: 각 달(month)의 마지막 날
# - MS: 각 달의 첫날
# - BM: 주말이 아닌 평일 중에서 각 달의 마지막 날
# - BMS: 주말이 아닌 평일 중에서 각 달의 첫날
# - WOM-2THU: 각 달의 두번째 목요일
# - Q-JAN: 각 분기의 첫달의 마지막 날
# - Q-DEC: 각 분기의 마지막 달의 마지막 날freq 인수로 특정한 날짜만 생성되도록 할 수도 있습니다. 많이 사용되는 -freq 인수값은 다음과 같습니다.
# - s: 초
# - T: 분
# - H: 시간
# - D: 일(day)
# - B: 주말이 아닌 평일
# - W: 주(일요일)
# - W-MON: 주(월요일)
# - M: 각 달(month)의 마지막 날
# - MS: 각 달의 첫날
# - BM: 주말이 아닌 평일 중에서 각 달의 마지막 날
# - BMS: 주말이 아닌 평일 중에서 각 달의 첫날
# - WOM-2THU: 각 달의 두번째 목요일
# - Q-JAN: 각 분기의 첫달의 마지막 날
# - Q-DEC: 각 분기의 마지막 달의 마지막 날

# %%
# B는 주말이 아닌 평일을 가르킴
pd.date_range("2018-4-1", "2018-4-30", freq="B")
# Out:
# DatetimeIndex(['2018-04-02', '2018-04-03', '2018-04-04', '2018-04-05',
#                '2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11',
#                '2018-04-12', '2018-04-13', '2018-04-16', '2018-04-17',
#                '2018-04-18', '2018-04-19', '2018-04-20', '2018-04-23',
#                '2018-04-24', '2018-04-25', '2018-04-26', '2018-04-27',
#                '2018-04-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range("2018-1-1", "2018-12-31", freq="W")
# Out:
# DatetimeIndex(['2018-01-07', '2018-01-14', '2018-01-21', '2018-01-28',
#                '2018-02-04', '2018-02-11', '2018-02-18', '2018-02-25',
#                '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25',
#                '2018-04-01', '2018-04-08', '2018-04-15', '2018-04-22',
#                '2018-04-29', '2018-05-06', '2018-05-13', '2018-05-20',
#                '2018-05-27', '2018-06-03', '2018-06-10', '2018-06-17',
#                '2018-06-24', '2018-07-01', '2018-07-08', '2018-07-15',
#                '2018-07-22', '2018-07-29', '2018-08-05', '2018-08-12',
#                '2018-08-19', '2018-08-26', '2018-09-02', '2018-09-09',
#                '2018-09-16', '2018-09-23', '2018-09-30', '2018-10-07',
#                '2018-10-14', '2018-10-21', '2018-10-28', '2018-11-04',
#                '2018-11-11', '2018-11-18', '2018-11-25', '2018-12-02',
#                '2018-12-09', '2018-12-16', '2018-12-23', '2018-12-30'],
# ...

# %% [markdown]
# 시계열 데이터의 인덱스는 시간이나 날짜를 나타내기 때문에 날짜 이동 등의 다양한 연산이 가능합니다. 예를 들어 shift 연산을 사용하면 인덱스는 그대로 두고 데이터만 이동할 수도 있습니다.

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(4), index=pd.date_range(
    "2018-1-1", periods=4, freq="M"))
ts
# Out:
# 2018-01-31    1.764052
# 2018-02-28    0.400157
# 2018-03-31    0.978738
# 2018-04-30    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(1)
# Out:
# 2018-01-31         NaN
# 2018-02-28    1.764052
# 2018-03-31    0.400157
# 2018-04-30    0.978738
# Freq: M, dtype: float64

# %%
ts.shift(-1)
# Out:
# 2018-01-31    0.400157
# 2018-02-28    0.978738
# 2018-03-31    2.240893
# 2018-04-30         NaN
# Freq: M, dtype: float64

# %%
ts.shift(1, freq="M")
# Out:
# 2018-02-28    1.764052
# 2018-03-31    0.400157
# 2018-04-30    0.978738
# 2018-05-31    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(1, freq="W")
# Out:
# 2018-02-04    1.764052
# 2018-03-04    0.400157
# 2018-04-01    0.978738
# 2018-05-06    2.240893
# dtype: float64

# %% [markdown]
# dattime자료형 Series에는 dt접근자가 있어 datetime 자료형이 가진 몇가지 유용한 메서드 상용 가능

# %%
s = pd.Series(pd.date_range("2020-12-25", periods=100, freq="D"))
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %% [markdown]
# 예를 들어 year, month, day, weekday 등의 속성을 이용하면 년, 월, 일, 요일 정보를 뺴낼 수 있다.

# %%
s.dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
#       ...
# 95    2021
# 96    2021
# 97    2021
# 98    2021
# 99    2021
# Length: 100, dtype: int64

# %%
s.dt.weekday
# Out:
# 0     4
# 1     5
# 2     6
# 3     0
# 4     1
#      ..
# 95    1
# 96    2
# 97    3
# 98    4
# 99    5
# Length: 100, dtype: int64

# %% [markdown]
# strftime(string format time) 메서드를 이용하여 문자열을 만드는 것도 가능.

# %%
s.dt.strftime("%Y년 %m월 %d일")
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object

# %% [markdown]
# DataFrame 그룹 연산 메서드
# 예를 들어 다음과 같은 데이터가 있을 때 key1의 값(A 또는 B)에 따른 data1

# %%
np.random.seed(0)
df2 = pd.DataFrame({
    'key1': ['A', 'A', 'B', 'B', 'A'],
    'key2': ['one', 'two', 'one', 'two', 'one'],
    'data1':[1, 2, 3, 4, 5],
    'data2':[10, 20, 30, 40, 50]
})
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
groups = df2.groupby(df2.key1)
groups

# %%
groups.groups
# Out:
# {'A': [0, 1, 4], 'B': [2, 3]}

# %% [markdown]
# A그룹과 B그룹 데이터의 합계를 구하기 위해 sum이라는 그룹연산을 한다.

# %%
groups.sum()
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
df2.data1.groupby(df2.key1).sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2.groupby(df2.key1)["data1"].sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2.groupby(df2.key1).sum()["data1"]
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %% [markdown]
# 복합 키 (key1, key2) 값에 따른 data1의 합계를 구하자. 분석하고자 하는 키가 복수이면 리스트를 사용한다.

# %%
df2.data1.groupby([df2.key1, df2.key2]).sum()
# Out:
# key1  key2
# A     one     6
#       two     2
# B     one     3
#       two     4
# Name: data1, dtype: int64

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
df1["인구"].groupby([df1["지역"], df1["연도"]]).sum().unstack("연도")
# Out:
# 연도      2005     2010      2015
# 지역
# 경상권  3512547  3393191   3448737
# 수도권  9762546  9894685  12794763

# %%
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
def peak_ro_peak_ratio(x):
    return x.max() / x.min()

iris.groupby(iris.sepcies)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22944\2300557112.py in <module>
#       2     return x.max() / x.min()
#       3
# ----> 4 iris.groupby(iris.sepcies)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sepcies'

# %%
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["alive"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
def change_boolean(value):
    if value == 'yes':
        return True
    else:
        return False

# %%
# change_boolean(titanic["alive"])
titanic["alive"] = titanic["alive"].apply(change_boolean)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone
# 0    man        True  NaN  Southampton  False  False
# 1  woman       False    C    Cherbourg  False  False
# 2  woman       False  NaN  Southampton  False   True
# 3  woman       False    C  Southampton  False  False
# 4    man        True  NaN  Southampton  False   True

# %%
# change_boolean(titanic["alive"])
titanic["alive"] = titanic.apply(lambda r: True if r.alive == 'yes' else False, axis=1)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone
# 0    man        True  NaN  Southampton  False  False
# 1  woman       False    C    Cherbourg  False  False
# 2  woman       False  NaN  Southampton  False   True
# 3  woman       False    C  Southampton  False  False
# 4    man        True  NaN  Southampton  False   True

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# Matplotlib는 파이썬에서 자료를 차트나 플롯으로 시각화하는 패키지입니다. Matplotlib는 다음과 같은 정형화된 차트나 플롯 이외에도 저수준API를 사용한 다양한 시각화 기능을 제공합니다.
# - 라인 플롯
# - 스캐터 플롯
# - 컨투어 플롯
# - 서피스 플롯
# - 바 차트
# - 히스토그램
# - 박스 플롯

# %% [markdown]
# 맷플로리브 패키지에는 pyplot라는 서브패키지가 존재. matlab이라는 수치해석 소프트웨어의 시각화 명령 제공. 간단한 시각화 프로그램을 만드는 경우에는 pyplot 서브패키지의 명령만으로도 충분합니다.
# 맷플로리브 패키지를 사용할 떄는 보통 다음과 같이 주 패키지는 mpl이라는 별칭(alias)으로 임포트하고 pyplot 서브패키지는 polt라는 다른 별칭으로 임포트하여 사용하는 것이 관례입니다.

# %% [markdown]
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %% [markdown]
# 그래프가 출력되지 않는다면 "%matplotlib inline" 명령해야 함. 주피터랩(interactive python)의 경우 별도의 윈도우를 띄워서 Figure를 표현하지 않기 때문에 경우에 따라서 그래프가 출력되지 않을 수도 있다.

# %%
# %matplotlib inline

# %%
matplotlib.pyplot.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22944\2772994140.py in <module>
# ----> 1 matplotlib.pyplot.plot()
#
# NameError: name 'matplotlib' is not defined

# %% [markdown]
# x축의 위치를 x틱(tick)이라고 합니다. default는 0, 1, ..., N-1 범위의 index array입니다.
# x tick을 지정하려면 두 개의 같은 길이의 리스트 혹은 배열 자료를 넣으면 됩니다.

# %%
plt.title("Plot")
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# 라인 플롯: show()는 플롯을 그림으로 표시합니다.

# %% [markdown]
# 한글폰트 사용하기. 한글 제목을 위해 title()의 인수로 한글 문자열을 전달하면 아래처럼 제대로 표현되지 않음을 확인할 수 있다.

# %%
plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
[matplotlib.font_manager.FontProperties(fname=font).get_name() for font in font_list if 'Nanum' in font]
# Out:
# ['NanumSquare',
#  'NanumBarunGothic',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumBarunpen',
#  'NanumGothic',
#  'NanumSquare',
#  'NanumBarunpen',
#  'NanumSquare',
#  'NanumBarunpen',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumGothic',
#  'NanumBarunpen',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumGothic',
#  'Nanum Pen Script',
#  'NanumGothic',
#  'NanumBarunGothic',
#  'Nanum Pen Script',
#  'NanumBarunGothic',
#  'Nanum Brush Script',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'Nanum Brush Script',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumBarunGothic']

# %%
# mpl.rcParams['font.family'] = 'NanumGothic'
mpl.rc('font', family='NanumGothic')
# mpl.rc('axes
mpl.rc('axes', unicode_minus=False)

# %%
global_font = {'family': 'NanumGothic', 'size':12, 'weight':'bold'}

# 폰트 설정
mpl.rc('font', **global_font) # pass in the font dict as kwargs
# mpl.rc('font', 'family': 'NanumGothic', 'size':24, 'weight': 'bold')와 같이 동작합니다.

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 레이블")
plt.ylabel("와이축 레이블")
plt.show()

# %% [markdown]
# 음수 부호를 유니코드와 아스키 중 어떤 문자로 표기할지 설정합니다. rc() 메서드로 RcParams 중 axes.unicode_minus의 값을 False로 변경하면 아스키의 문자로 표현됩니다.

# %%
mpl.rc('axes', unicode_minus=False)
# 유니코드에서 음수 부호 설정

# %%
plt.title("default 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rp--')
plt.show()

# %% [markdown]
# 스타일 문자열은 색상, 마커, 선 종류의 순서로 지정한다. 만약 이 중 일부가 생략되면 디폴트 값이 적용됩니다.

# %% [markdown]
# https://matplotlib.org/2.0.2/examples/color/named_colors.html
# 흰색_확인_표시
# 두_눈
# 두_손을_들고_있는_사람
#
#
#
#
#
# 4:12
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markershttps://matplotlib.org/2.0.2/examples/color/named_colors.html
# 흰색_확인_표시
# 두_눈
# 두_손을_들고_있는_사람
#
#
#
#
#
# 4:12
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers

# %% [markdown]
# solid line: '-' or 'solid'
# dashed line: '--' or 'dashed'
# dash-dotted line: '-.' or 'dashdot'

# %% [markdown]
# https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c='b',
         lw=5, ls='--', marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %%
plt.title("x축 y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# 플롯이나 차트에서 축상의 위치 표시 지점을 틱이라고 하고 이 틱에 써진 숫자 혹은 글자를 틱 라벨이라고 합니다. 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks()이나 yticks()을 사용합니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %% [markdown]
# 틱 라벨 문자열에는 $$사이에 수학 문자식을 넣을 수도 있습니다. 다양한 mathematical expresssons은 아래 링크를 통해 확인할 수 있습니다.
# https://matplotlib.org/3.1.1/tutorials/text/mathtext.htmlhttps://matplotlib.org/3.1.1/tutorials/text/mathtext.html

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("TeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], ["Low", "Zero", "High"])
plt.show()

# %% [markdown]
# 라인 플롯에서 선을 하나가 아니라 여러개를 그리고 싶은 경우에는 x데이터, y데이터, 스타일 문자열을 반복하여 인수로 넘깁니다. 이 경우에는 하나의 선을 그릴 때 처럼 x 데이터나 스타일 문자열을 생략할 수 없습니다.

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %% [markdown]
# 하나의 plot()이 아니라 복수의 plot()을 하나의 그림에 겹쳐서 그릴 수도 있다.

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 = {"c":"b", "lw":5, "l2":5, "ls":"--", "marker":"o", "ms":15, "mec":"g", "mew":5, "mfc":"r"}
style2 = {"c":"k", "lw":3, "l2":5, "ls":":", "marker":"s", "ms":10, "mec":"m", "mew":5, "mfc":"c"}
plt.plot([1, 4, 9, 16], **style1)
plt.plot([9, 16, 4, 1], **style2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22944\1152795083.py in <module>
#       2 style1 = {"c":"b", "lw":5, "l2":5, "ls":"--", "marker":"o", "ms":15, "mec":"g", "mew":5, "mfc":"r"}
#       3 style2 = {"c":"k", "lw":3, "l2":5, "ls":":", "marker":"s", "ms":10, "mec":"m", "mew":5, "mfc":"c"}
# ----> 4 plt.plot([1, 4, 9, 16], **style1)
#       5 plt.plot([9, 16, 4, 1], **style2)
#       6
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %% [markdown]
# ### 범례 Legend
# 여러개의 라인 플롯을 동시에 그리는 경우에는 각 선이 무슨 자료를 표시하는지를 보여주기 위해 legend 명령으로 범례(legend)를 추가할 수 있습니다. 범례의 위치는 자동으로 정해지지만 수동으로 설정하고 시프면 loc 키워드 인수를 사용합니다.

# %% [markdown]
# 아래 예제에서는 각 plot마다 label 키워드 인수를 통해 legend label을 설정하고 legend() 메서드에 loc키워드 인자에 2를 전달함으로써 좌측 상단에 legend 위치하라고 명시하고 있습니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2) #upper left
plt.show()

# %% [markdown]
# 플롯의 x축 위치와 y축 위치에는 각각 그 데이터가 의미하는 바를 표시하기 위해 라벨(label)를 추가할 수 있습니다. 라벨을 붙이려면 xlabel(), ylabel()을 사용합니다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, ls="--", label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
x = np.linspace(32, 100, 100-32) # x = np.arange(32, 100)
y = (x - 32) * 5/9
plt.title("섭씨 온도와 화씨 온도")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.plot(x, y, 'r-.')
plt.show()

# %% [markdown]
# ### Figure
# Matplotlib는 data를 Figure(ex. windows, jupyter widgets, etc)에 x-y 좌표의 그래프로 표시합니다. 각각의 FIgure는 하나 이상의 Axes를 갖습니다.
#
# 가장 간단하게 Figure, Axes 객체를 만드는 방법은 pyplot.subplots()을 사용하는 것입니다. 그 후 Axes.plot()를 활용하여 Axes에 데이터를 그립니다.

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);

# %% [markdown]
# Figure는 전체 그림(그래프)을 의미하는 객체입니다. Figure객체는 Axes, 특수 Artist 그룹(title, figure legends, colorbar, etc), 그리고 심지어 중첩된 subfigures까지 포함할 수 있습니다.
#
# 가장 쉬운 방버으로 figure객체를 생성하는 방버들입니다. Axes 없이 figure만 얻으려면 figure()메서드를 사용하면 됩니다. 1개의 Axes 객체를 갖는 figure를 만들기 위해선 subplots()메서드를 인수 없이 사용하면 됩니다. grid 형태의 shape을 갖는 axes 객체를 여럿 만들 땐 subplot() 메서드에 첫 인수로  row를 두번째 인수로 column을 입력합니다.

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)

# %% [markdown]
# 일반적으로는 figure잘 사용 안함. plot만 해도 생성 해줘서. 그림의 크기 설정할 때 figure() 사. figsize 인수로 설정

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.title("figure size: (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# Figure객체 얻으려면 gcf() 메서드 사용

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2190329514496
# Figure(640x480) 2190329514496

# %% [markdown]
# ### Axes
# Figure 객체 안에 여러 개의 플롯을 그리드 형태로 보여야하는 경우도 잇습니다. Figure 안에 있는 각각의 플롯은 Axes라고 불리는 객체에 속합니다.
# Figure 안에 Axes를 생성하려면 원래 subplot()을 사용하여 명시적으로  Axes 객체를 얻어야 합니다. 그러나 plot()을 바로 사용해도 자동으로 Figure, Axes 객체를 생성해줍니다.

# %% [markdown]
# subplot()은 그리드 형태의 Axes 객체들을 생성합니다. figure가 행렬(matrix)이고 Axes가 행렬의 원소라고 생각하면 됩니다.
#
# 예를 들어 위와 아래 두개의 플롯이 있는 경우 행이 2이고 열이 1인 2x1 행렬입니다.
# subplot 명령은 세개의 인수를 가지는데 처음 두개의 원소가 전체 그리드 행렬의 모양을 지시하는 두 숫자이고 세번쨰 인수가 네 개 중 어느 것인지를 의미하는 숫자가 됩니다.

# %%
ax1 = plt.subplot(2, 1, 1)
ax2 = plt.subplot(2, 1, 2)
